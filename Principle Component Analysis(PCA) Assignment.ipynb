# %%
import pandas as pd
df = pd.read_csv("wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.shape
# Out:
# (178, 14)

# %%
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Histograms

# %%
df.hist(figsize =(12,10),bins = 20)
plt.suptitle("Feature Distributions")
plt.show()

# %% [markdown]
# # Box Plots

# %%
plt.figure(figsize=(12,6))
sns.boxplot(df,orient ='h')
plt.title("Box Plot of Features")
plt.show()

# %%
correlation_matrix=df.corr()
correlation_matrix
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.328222  0.437776 -0.049643    0.517859
# Alcohol         -0.328222  1.000000  0.094397  0.211545   -0.310235
# Malic            0.437776  0.094397  1.000000  0.164045    0.288500
# Ash             -0.049643  0.211545  0.164045  1.000000    0.443367
# Alcalinity       0.517859 -0.310235  0.288500  0.443367    1.000000
# Magnesium       -0.209179  0.270798 -0.054575  0.286587   -0.083333
# Phenols         -0.719163  0.289101 -0.335167  0.128980   -0.321113
# Flavanoids      -0.847498  0.236815 -0.411007  0.115077   -0.351370
# Nonflavanoids    0.489109 -0.155929  0.292977  0.186230    0.361922
# Proanthocyanins -0.499130  0.136698 -0.220746  0.009652   -0.197327
# Color            0.265668  0.546364  0.248985  0.258887    0.018732
# Hue             -0.617369 -0.071747 -0.561296 -0.074667   -0.273955
# Dilution        -0.788230  0.072343 -0.368710  0.003911   -0.276769
# ...

# %% [raw]
# Observation:
# >Feature Correlations: We notice some features with strong positive correlations like Alcohol and Quality and others with negative correlations like volatile,acidity etc..
# >Distribution:Most freaturs are not normally distributed,which justifies the need to standardize them for PCA.

# %% [markdown]
# # Dimensionality Reduction with PCA:

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
scaler = StandardScaler()# standardize the data(mean =0,std =1)
data_scaled = scaler.fit_transform(df)

# %%
pca = PCA()
pca.fit(data_scaled)
# Out:
# PCA()

# %%
#Scree Plot
plt.figure(figsize=(10,5))
plt.plot(range(1,len(df.columns)+1),pca.explained_variance_ratio_,marker ='o')
plt.xlabel("Principal Component")
plt.ylabel("Explained Variance Ratio")
plt.title("Scree Plot")
plt.show()

# %%
import numpy as np
#cumulative explained variance plot
cum_var = np.cumsum(pca.explained_variance_ratio_)
plt.figure(figsize =(10,5))
plt.plot(range(1,len(cum_var)+1),cum_var,marker="o")
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance Plot')
plt.show()

# %%
#optimal number of components
optimal_components = np.argmax(cum_var >= 0.95) + 1
print("Optimal Number of Components:",{optimal_components})
# Out:
# Optimal Number of Components: {10}

# %%
#transform data into principal components
pca = PCA(n_components = optimal_components)
data_pca = pca.fit_transform(data_scaled)
print("Shape of PCA transformed Data:",data_pca.shape)
# Out:
# Shape of PCA transformed Data: (178, 10)

# %% [raw]
# The original dataset has been transformed into a lower - dimensoinal space.

# %% [markdown]
# # Clustering with Original Data:

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
#Apply Kmeans
kmeans_orig = KMeans(n_clusters = 3,random_state = 42)
kmeans_orig.fit(data_scaled)
labels_orig = kmeans_orig.labels_
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.scatter(data_scaled[:,0],data_pca[:,1],c=labels_orig,cmap = 'viridis')
plt.title("K-means Clustering on Original Data(Visualized using PCA)")
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.show()

# %%
#silhouette score of original data
sil_score_orig = silhouette_score(data_scaled,labels_orig)
print("Silhouette Score(Original data):",sil_score_orig.round(3))
# Out:
# Silhouette Score(Original data): 0.308

# %% [raw]
# > K-Means clustering algorithm forms 3 clusters.
# >Silhouette Score will provide insights into the compactness and seperation if clusters.

# %% [markdown]
# # Clustering with PCA:

# %%
kmeans_pca = KMeans(n_clusters = 3 , random_state =42)
kmeans_pca.fit(data_pca)
labels_pca = kmeans_pca.labels_
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.scatter(data_pca[:,0],data_pca[:,1],c=labels_pca,cmap='viridis')
plt.title('K-Means Clustering on PCA transformed data')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.show()

# %%
#silhouette score
sil_score_pca = silhouette_score(data_pca,labels_pca)
print("Silhouette score (PCA data):",sil_score_pca.round(3))
# Out:
# Silhouette score (PCA data): 0.324

# %% [markdown]
# # Comparision:

# %%
#silhouette scores:
print("Silhouette Score(Original data):",sil_score_orig.round(3))
print("Silhouette score (PCA data):",sil_score_pca.round(3))

#differences in cluster labels
cluster_diff = np.sum(labels_orig != labels_pca)
print("Number of Different lables:",cluster_diff)
# Out:
# Silhouette Score(Original data): 0.308
# Silhouette score (PCA data): 0.324
# Number of Different lables: 0

# %% [raw]
# > Silhouette Score of PCA data is higher to that from the original data.
# > There is no change in Label difference due to the dimensionality reduction.

# %% [markdown]
# # Conclusion:

# %% [raw]
# >Dimentionality Reduction:PCA reduced the number of features while retaining most of the variance.
# >Clustering Performance: K-Means clustering performed comparbly well on both original and PCA transformed datasets.
# >Trade-offs: Using PCA can simplify models and imporve computational efficiency,but some interpretability of the original features is lost.
# >Recommendation: PCA is beneficial when dealing with high-dimensional data or when features are highly correlated.
